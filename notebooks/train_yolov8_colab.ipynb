# %% [markdown]
# # Treinamento YOLOv8 - FIAP Threat Model AI
# Use este notebook no Google Colab ou Kaggle com GPU habilitada.

# %%
# !pip install ultralytics -q

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !unzip -q fiap_dataset_medio_drawio_yolo.zip -d /content/dataset

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
model.train(data='/content/dataset/fiap_dataset_medio_drawio/dataset.yaml', epochs=50, imgsz=640, batch=16)

# %%
from google.colab import files
files.download('/content/runs/detect/train/weights/best.pt')
